# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ---------------------------------------- 4.0/4.0 MB 15.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.0/4.0 MB 32.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.0/4.0 MB 32.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.0/4.0 MB 14.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.0/4.0 MB 31.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.0/4.0 MB 31.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.0/4.0 MB 9.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.0/4.0 MB 31.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.9/3.9 MB 13.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.9/3.9 MB 27.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.7/2.7 GB ? eta 0:00:00
# ...
#   Attempting uninstall: torch
# ...

# %%
pip install opencv-python
# Out:
# ...
#      --------------------------------------- 38.8/38.8 MB 19.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# C:\Users\manis\anaconda3\lib\site-packages\torch\hub.py:294: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\manis/.cache\torch\hub\master.zip
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\manis\AppData\Roaming\Ultralytics\settings.json'
# ...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
img = 'https://nmaahc.si.edu/sites/default/files/styles/max_1300x1300/public/images/header/audience-citizen_0.jpg?itok=unjNTfkP'

# %%
results = model(img)
results.print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 results = model(img)
#       2 results.print()
#
# NameError: name 'model' is not defined

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 results.render()
#
# NameError: name 'results' is not defined

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 6
#       3 ret, frame = cap.read()
#       5 # Make detections
# ----> 6 results = model(frame)
#       8 cv2.imshow('YOLO', np.squeeze(results.render()))
#      10 if cv2.waitKey(10) & 0xFF == ord('q'):
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
# ...

# %%
import uuid 
import os
import time

# %%
# IMAGES_PATH = os.path.join('data', 'images') #/data/images
IMAGES_PATH = 'C:/Users/bhara/yolov5/data/capturedImages'
labels = ['hello', 'thanks', 'hurt', 'help', 'iloveyou']
number_imgs = 25

# %%
cap = cv2.VideoCapture(0)

for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        ret, frame = cap.read()
        
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        cv2.imwrite(imgname, frame)
        
        cv2.imshow('Image Collection', frame)
        
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 cap = cv2.VideoCapture(0)
# ----> 3 for label in labels:
#       4     print('Collecting images for {}'.format(label))
#       5     time.sleep(5)
#
# NameError: name 'labels' is not defined

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# The system cannot find the path specified.

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='C:/Users/bhara/yolov5/runs/train/exp18/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\bhara/.cache\torch\hub\master.zip
# YOLOv5  2024-5-4 Python-3.11.7 torch-2.3.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
imgSample = "C:/Users/bhara/yolov5/data/capturedImages/iloveyou.28eb117b-0a27-11ef-928e-8cf8c544d594.jpg"

# %%
results = model(imgSample)
results.print()
# Out:
# image 1/1: 480x640 1 iloveyou
# Speed: 16.0ms pre-process, 210.1ms inference, 3.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
